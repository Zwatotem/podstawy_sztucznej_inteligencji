# %% [markdown]
# # Regresja

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import cross_val_predict
from sklearn import datasets, linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection
from sklearn import  metrics
from statsmodels.formula.api import ols

# %% [markdown]
# Rozważmy zbiór Boston

# %%
boston = datasets.load_boston()
# print description
# print(boston.DESCR)
# Out:
# C:\Users\zwato\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
print(boston.keys())
print(boston.data.shape)
print(boston.feature_names)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])
# (506, 13)
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
# get the data
boston_X = boston.data
boston_Y = boston.target

# Split the data into training/testing sets
boston_X_train = boston_X[:-50]
boston_X_test = boston_X[-50:]
 
# Split the targets into training/testing sets
boston_y_train = boston_Y[:-50]
boston_y_test = boston_Y[-50:]

# %%
bos=pd.DataFrame(boston.data[:-50])
bos.columns = boston.feature_names
bos['PRICE']=boston.target[:-50]
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
bos1=pd.DataFrame(boston_X[-50:])
bos1.columns = boston.feature_names
bos1['PRICE']=boston.target[-50:]
bos1.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 0  4.66883  0.0   18.1   0.0  0.713  5.976  87.9  2.5806  24.0  666.0
# 1  8.20058  0.0   18.1   0.0  0.713  5.936  80.3  2.7792  24.0  666.0
# 2  7.75223  0.0   18.1   0.0  0.713  6.301  83.7  2.7831  24.0  666.0
# 3  6.80117  0.0   18.1   0.0  0.713  6.081  84.4  2.7175  24.0  666.0
# 4  4.81213  0.0   18.1   0.0  0.713  6.701  90.0  2.5975  24.0  666.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     20.2   10.48  19.01   12.7
# 1     20.2    3.50  16.94   13.5
# 2     20.2  272.21  16.23   14.9
# 3     20.2  396.90  14.70   20.0
# 4     20.2  255.23  16.42   16.4

# %%
model = ols("PRICE ~ RM**2+ZN**2+ZN*RM*AGE*INDUS*np.log(DIS)*TAX*LSTAT*NOX*B", bos).fit()
# Print the summary
print((model.summary2()))
# Out:
#                                  Results: Ordinary least squares
# ==================================================================================================
# Model:                          OLS                        Adj. R-squared:               0.951
# Dependent Variable:             PRICE                      AIC:                          2017.4344
# Date:                           2022-03-31 14:03           BIC:                          3435.5719
# No. Observations:               456                        Log-Likelihood:               -664.72
# Df Model:                       343                        F-statistic:                  26.84
# Df Residuals:                   112                        Prob (F-statistic):           2.48e-55
# R-squared:                      0.988                      Scale:                        4.3997
# --------------------------------------------------------------------------------------------------
#                                               Coef.   Std.Err.    t    P>|t|    [0.025     0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                                    -22.2879  65.5290 -0.3401 0.7344  -152.1253  107.5494
# RM                                          -207.4663 261.1030 -0.7946 0.4285  -724.8085  309.8759
# ZN                                           -13.1008  13.8140 -0.9484 0.3450   -40.4715   14.2699
# ZN:RM                                          8.1952  11.3838  0.7199 0.4731   -14.3603   30.7506
# AGE                                         -148.2458 271.2476 -0.5465 0.5858  -685.6881  389.1965
# ZN:AGE                                        -2.3938   3.8128 -0.6278 0.5314    -9.9483    5.1607
# RM:AGE                                       158.1704 203.3037  0.7780 0.4382  -244.6499  560.9907
# ZN:RM:AGE                                      2.4883   4.0323  0.6171 0.5384    -5.5012   10.4778
# INDUS                                        -33.1311 308.8368 -0.1073 0.9148  -645.0516  578.7893
# ZN:INDUS                                      -3.1551   3.5172 -0.8970 0.3716   -10.1241    3.8138
# RM:INDUS                                     137.2750 442.3695  0.3103 0.7569  -739.2235 1013.7735
# ZN:RM:INDUS                                   -1.8695   2.1976 -0.8507 0.3968    -6.2238    2.4849
# AGE:INDUS                                    -75.6563  87.1730 -0.8679 0.3873  -248.3783   97.0658
# ZN:AGE:INDUS                                   0.4374   1.2379  0.3534 0.7245    -2.0153    2.8902
# RM:AGE:INDUS                                   4.3334  19.0951  0.2269 0.8209   -33.5011   42.1680
# ZN:RM:AGE:INDUS                               -1.3588   1.3694 -0.9923 0.3232    -4.0721    1.3545
# np.log(DIS)                                  -40.5515  64.2117 -0.6315 0.5290  -167.7787   86.6756
# ZN:np.log(DIS)                                -1.5596   2.9938 -0.5209 0.6034    -7.4914    4.3723
# RM:np.log(DIS)                              -513.1565 364.2569 -1.4088 0.1617 -1234.8848  208.5718
# ZN:RM:np.log(DIS)                              0.3171   3.0275  0.1047 0.9168    -5.6816    6.3157
# AGE:np.log(DIS)                             -100.6134 297.5435 -0.3381 0.7359  -690.1578  488.9310
# ZN:AGE:np.log(DIS)                            -0.1702   1.4448 -0.1178 0.9064    -3.0328    2.6924
# RM:AGE:np.log(DIS)                          -202.2392 173.7123 -1.1642 0.2468  -546.4278  141.9495
# ZN:RM:AGE:np.log(DIS)                         -0.6605   1.8933 -0.3488 0.7279    -4.4118    3.0909
# INDUS:np.log(DIS)                            138.1645 218.1308  0.6334 0.5278  -294.0338  570.3627
# ZN:INDUS:np.log(DIS)                           0.9728   0.4249  2.2897 0.0239     0.1310    1.8146
# RM:INDUS:np.log(DIS)                          14.6762 295.5009  0.0497 0.9605  -570.8209  600.1733
# ZN:RM:INDUS:np.log(DIS)                        0.1459   0.9190  0.1588 0.8741    -1.6750    1.9669
# AGE:INDUS:np.log(DIS)                        321.2047 129.8708  2.4733 0.0149    63.8824  578.5269
# ZN:AGE:INDUS:np.log(DIS)                       0.0323   0.9133  0.0354 0.9719    -1.7774    1.8419
# RM:AGE:INDUS:np.log(DIS)                     -40.3420  23.6136 -1.7084 0.0903   -87.1293    6.4452
# ZN:RM:AGE:INDUS:np.log(DIS)                   -0.3884   0.3993 -0.9728 0.3328    -1.1796    0.4027
# TAX                                          -32.1595 266.1620 -0.1208 0.9040  -559.5253  495.2063
# ZN:TAX                                        -0.0085   0.0269 -0.3160 0.7526    -0.0618    0.0448
# RM:TAX                                       115.6478  61.2114  1.8893 0.0614    -5.6347  236.9303
# ZN:RM:TAX                                     -0.0470   0.0881 -0.5336 0.5946    -0.2215    0.1275
# AGE:TAX                                       28.9999  18.8352  1.5397 0.1265    -8.3196   66.3194
# ZN:AGE:TAX                                     0.1065   0.0487  2.1871 0.0308     0.0100    0.2030
# RM:AGE:TAX                                    -6.0894   3.2293 -1.8857 0.0619   -12.4877    0.3090
# ZN:RM:AGE:TAX                                 -0.0204   0.0410 -0.4983 0.6193    -0.1016    0.0608
# INDUS:TAX                                      2.1751  14.7144  0.1478 0.8827   -26.9796   31.3298
# ZN:INDUS:TAX                                   0.0087   0.0497  0.1757 0.8608    -0.0898    0.1073
# RM:INDUS:TAX                                  -6.0839   3.9369 -1.5453 0.1251   -13.8845    1.7166
# ZN:RM:INDUS:TAX                                0.0712   0.1189  0.5993 0.5502    -0.1643    0.3067
# AGE:INDUS:TAX                                 -1.4795   1.1418 -1.2957 0.1977    -3.7419    0.7829
# ZN:AGE:INDUS:TAX                               0.0955   0.0849  1.1249 0.2630    -0.0727    0.2638
# RM:AGE:INDUS:TAX                               0.3116   0.1953  1.5957 0.1134    -0.0753    0.6986
# ZN:RM:AGE:INDUS:TAX                            0.0041   0.0318  0.1291 0.8975    -0.0589    0.0671
# np.log(DIS):TAX                              392.8410 298.5288  1.3159 0.1909  -198.6555  984.3376
# ZN:np.log(DIS):TAX                             0.0035   0.0101  0.3492 0.7276    -0.0164    0.0234
# RM:np.log(DIS):TAX                          -125.7021  63.5379 -1.9784 0.0503  -251.5944    0.1902
# ZN:RM:np.log(DIS):TAX                         -0.0638   0.1648 -0.3874 0.6992    -0.3904    0.2627
# AGE:np.log(DIS):TAX                          -24.6844  13.7183 -1.7994 0.0747   -51.8653    2.4966
# ZN:AGE:np.log(DIS):TAX                         0.1710   0.0962  1.7789 0.0780    -0.0195    0.3616
# RM:AGE:np.log(DIS):TAX                         5.1712   2.4576  2.1042 0.0376     0.3018   10.0406
# ZN:RM:AGE:np.log(DIS):TAX                     -0.0362   0.0432 -0.8383 0.4036    -0.1219    0.0494
# INDUS:np.log(DIS):TAX                        -37.4884  26.1685 -1.4326 0.1548   -89.3380   14.3612
# ZN:INDUS:np.log(DIS):TAX                      -0.0101   0.0810 -0.1242 0.9014    -0.1706    0.1504
# RM:INDUS:np.log(DIS):TAX                       8.7251   5.1070  1.7085 0.0903    -1.3938   18.8439
# ZN:RM:INDUS:np.log(DIS):TAX                    0.0389   0.0275  1.4134 0.1603    -0.0156    0.0934
# AGE:INDUS:np.log(DIS):TAX                      1.0480   0.8630  1.2144 0.2271    -0.6618    2.7579
# ZN:AGE:INDUS:np.log(DIS):TAX                  -0.0851   0.0643 -1.3231 0.1885    -0.2124    0.0423
# RM:AGE:INDUS:np.log(DIS):TAX                  -0.2261   0.1518 -1.4896 0.1391    -0.5269    0.0747
# ZN:RM:AGE:INDUS:np.log(DIS):TAX               -0.0071   0.0183 -0.3868 0.6996    -0.0434    0.0292
# LSTAT                                        123.8321  91.4312  1.3544 0.1783   -57.3272  304.9914
# ZN:LSTAT                                       0.0011   0.0012  0.9040 0.3679    -0.0013    0.0036
# RM:LSTAT                                     290.9624 398.8395  0.7295 0.4672  -499.2868 1081.2117
# ZN:RM:LSTAT                                    0.0074   0.0078  0.9523 0.3430    -0.0080    0.0228
# AGE:LSTAT                                    207.1748 295.0750  0.7021 0.4841  -377.4785  791.8280
# ZN:AGE:LSTAT                                   0.0143   0.0126  1.1352 0.2587    -0.0107    0.0393
# RM:AGE:LSTAT                                 -58.2684  52.6265 -1.1072 0.2706  -162.5410   46.0042
# ZN:RM:AGE:LSTAT                                0.1180   0.1078  1.0946 0.2760    -0.0956    0.3315
# INDUS:LSTAT                                 -476.2078 383.7823 -1.2408 0.2173 -1236.6233  284.2076
# ZN:INDUS:LSTAT                                 0.0016   0.0027  0.6059 0.5458    -0.0036    0.0069
# RM:INDUS:LSTAT                                55.7513  45.9044  1.2145 0.2271   -35.2023  146.7049
# ZN:RM:INDUS:LSTAT                              0.0121   0.0184  0.6593 0.5111    -0.0243    0.0485
# AGE:INDUS:LSTAT                               -1.9212  18.9587 -0.1013 0.9195   -39.4855   35.6431
# ZN:AGE:INDUS:LSTAT                             0.0075   0.0127  0.5888 0.5572    -0.0177    0.0327
# RM:AGE:INDUS:LSTAT                             1.6755   3.1659  0.5292 0.5977    -4.5974    7.9484
# ZN:RM:AGE:INDUS:LSTAT                          0.1367   0.1420  0.9628 0.3377    -0.1446    0.4180
# np.log(DIS):LSTAT                            254.4075 117.5384  2.1645 0.0326    21.5203  487.2947
# ZN:np.log(DIS):LSTAT                           0.0022   0.0021  1.0205 0.3097    -0.0020    0.0063
# RM:np.log(DIS):LSTAT                          88.7307 291.9910  0.3039 0.7618  -489.8120  667.2734
# ZN:RM:np.log(DIS):LSTAT                        0.0100   0.0131  0.7613 0.4481    -0.0160    0.0359
# AGE:np.log(DIS):LSTAT                         56.6141 187.3444  0.3022 0.7631  -314.5849  427.8131
# ZN:AGE:np.log(DIS):LSTAT                       0.0172   0.0154  1.1143 0.2675    -0.0133    0.0476
# RM:AGE:np.log(DIS):LSTAT                      11.4317  35.5008  0.3220 0.7480   -58.9085   81.7719
# ZN:RM:AGE:np.log(DIS):LSTAT                    0.1565   0.1325  1.1814 0.2399    -0.1060    0.4191
# INDUS:np.log(DIS):LSTAT                      714.8044 284.8546  2.5094 0.0135   150.4017 1279.2072
# ZN:INDUS:np.log(DIS):LSTAT                     0.0007   0.0046  0.1609 0.8725    -0.0084    0.0099
# RM:INDUS:np.log(DIS):LSTAT                  -123.6111  47.2155 -2.6180 0.0101  -217.1626  -30.0596
# ZN:RM:INDUS:np.log(DIS):LSTAT                  0.0135   0.0296  0.4572 0.6484    -0.0451    0.0722
# AGE:INDUS:np.log(DIS):LSTAT                  -29.9863  13.1854 -2.2742 0.0249   -56.1116   -3.8611
# ZN:AGE:INDUS:np.log(DIS):LSTAT                -0.0185   0.0222 -0.8311 0.4077    -0.0625    0.0255
# RM:AGE:INDUS:np.log(DIS):LSTAT                 3.7424   2.2151  1.6895 0.0939    -0.6464    8.1313
# ZN:RM:AGE:INDUS:np.log(DIS):LSTAT              0.0431   0.0303  1.4225 0.1576    -0.0169    0.1032
# TAX:LSTAT                                    283.4396 148.8027  1.9048 0.0594   -11.3939  578.2731
# ZN:TAX:LSTAT                                   0.0142   0.0119  1.1928 0.2355    -0.0094    0.0379
# RM:TAX:LSTAT                                 -55.3546  25.8344 -2.1427 0.0343  -106.5421   -4.1670
# ZN:RM:TAX:LSTAT                               -0.0711   0.0646 -1.1009 0.2733    -0.1990    0.0569
# AGE:TAX:LSTAT                                 -5.4113   2.0637 -2.6221 0.0100    -9.5002   -1.3223
# ZN:AGE:TAX:LSTAT                              -0.0691   0.0534 -1.2941 0.1983    -0.1750    0.0367
# RM:AGE:TAX:LSTAT                               1.0185   0.3627  2.8079 0.0059     0.2998    1.7373
# ZN:RM:AGE:TAX:LSTAT                            0.1112   0.0633  1.7564 0.0818    -0.0142    0.2367
# INDUS:TAX:LSTAT                              -15.3476   7.8895 -1.9453 0.0542   -30.9797    0.2845
# ZN:INDUS:TAX:LSTAT                            -0.0267   0.0285 -0.9395 0.3495    -0.0831    0.0296
# RM:INDUS:TAX:LSTAT                             2.9875   1.3879  2.1526 0.0335     0.2376    5.7374
# ZN:RM:INDUS:TAX:LSTAT                          0.0039   0.0294  0.1324 0.8949    -0.0543    0.0621
# AGE:INDUS:TAX:LSTAT                            0.2887   0.1155  2.4990 0.0139     0.0598    0.5176
# ZN:AGE:INDUS:TAX:LSTAT                        -0.0060   0.0179 -0.3380 0.7360    -0.0414    0.0294
# RM:AGE:INDUS:TAX:LSTAT                        -0.0543   0.0203 -2.6705 0.0087    -0.0947   -0.0140
# ZN:RM:AGE:INDUS:TAX:LSTAT                     -0.0262   0.0173 -1.5145 0.1327    -0.0605    0.0081
# np.log(DIS):TAX:LSTAT                       -274.5348 118.9044 -2.3089 0.0228  -510.1287  -38.9409
# ZN:np.log(DIS):TAX:LSTAT                       0.0747   0.0586  1.2753 0.2048    -0.0414    0.1908
# RM:np.log(DIS):TAX:LSTAT                      49.1689  20.5461  2.3931 0.0184     8.4594   89.8784
# ZN:RM:np.log(DIS):TAX:LSTAT                    0.0646   0.0615  1.0496 0.2962    -0.0573    0.1865
# AGE:np.log(DIS):TAX:LSTAT                      4.1419   2.0909  1.9809 0.0501    -0.0010    8.2848
# ZN:AGE:np.log(DIS):TAX:LSTAT                   0.0128   0.0377  0.3388 0.7354    -0.0620    0.0876
# RM:AGE:np.log(DIS):TAX:LSTAT                  -0.7665   0.3565 -2.1504 0.0337    -1.4728   -0.0602
# ZN:RM:AGE:np.log(DIS):TAX:LSTAT               -0.0511   0.0309 -1.6535 0.1010    -0.1124    0.0101
# INDUS:np.log(DIS):TAX:LSTAT                   15.4569   6.3707  2.4262 0.0169     2.8341   28.0797
# ZN:INDUS:np.log(DIS):TAX:LSTAT                -0.0167   0.0314 -0.5326 0.5954    -0.0790    0.0455
# RM:INDUS:np.log(DIS):TAX:LSTAT                -2.7252   1.1085 -2.4584 0.0155    -4.9216   -0.5288
# ZN:RM:INDUS:np.log(DIS):TAX:LSTAT             -0.0032   0.0192 -0.1652 0.8691    -0.0413    0.0349
# AGE:INDUS:np.log(DIS):TAX:LSTAT               -0.2027   0.1170 -1.7331 0.0858    -0.4345    0.0290
# ZN:AGE:INDUS:np.log(DIS):TAX:LSTAT             0.0298   0.0219  1.3622 0.1759    -0.0136    0.0732
# RM:AGE:INDUS:np.log(DIS):TAX:LSTAT             0.0377   0.0199  1.8971 0.0604    -0.0017    0.0771
# ZN:RM:AGE:INDUS:np.log(DIS):TAX:LSTAT          0.0097   0.0073  1.3358 0.1843    -0.0047    0.0241
# NOX                                          -21.7675  21.1292 -1.0302 0.3051   -63.6322   20.0973
# ZN:NOX                                         0.0002   0.0002  1.0209 0.3095    -0.0002    0.0005
# RM:NOX                                      -159.9020 111.2076 -1.4379 0.1533  -380.2456   60.4416
# ZN:RM:NOX                                      0.0010   0.0010  0.9662 0.3360    -0.0010    0.0030
# AGE:NOX                                     -175.9191 140.8724 -1.2488 0.2143  -455.0397  103.2015
# ZN:AGE:NOX                                     0.0036   0.0033  1.0729 0.2856    -0.0030    0.0102
# RM:AGE:NOX                                  -228.9941 362.8264 -0.6311 0.5292  -947.8881  489.8998
# ZN:RM:AGE:NOX                                  0.0237   0.0248  0.9551 0.3416    -0.0254    0.0728
# INDUS:NOX                                   -159.0433  80.6820 -1.9712 0.0512  -318.9044    0.8178
# ZN:INDUS:NOX                                   0.0003   0.0005  0.7377 0.4622    -0.0006    0.0012
# RM:INDUS:NOX                                -641.9246 804.7502 -0.7977 0.4268 -2236.4340  952.5849
# ZN:RM:INDUS:NOX                                0.0025   0.0031  0.8080 0.4208    -0.0036    0.0085
# AGE:INDUS:NOX                                 96.1389 157.8543  0.6090 0.5437  -216.6291  408.9069
# ZN:AGE:INDUS:NOX                               0.0083   0.0089  0.9322 0.3532    -0.0093    0.0259
# RM:AGE:INDUS:NOX                               4.3950  35.3199  0.1244 0.9012   -65.5868   74.3769
# ZN:RM:AGE:INDUS:NOX                            0.0580   0.0635  0.9143 0.3625    -0.0677    0.1838
# np.log(DIS):NOX                              -22.3690  34.2003 -0.6541 0.5144   -90.1325   45.3945
# ZN:np.log(DIS):NOX                             0.0002   0.0003  0.8038 0.4232    -0.0004    0.0009
# RM:np.log(DIS):NOX                          -199.6102 180.1532 -1.1080 0.2702  -556.5607  157.3403
# ZN:RM:np.log(DIS):NOX                          0.0015   0.0018  0.8314 0.4075    -0.0021    0.0052
# AGE:np.log(DIS):NOX                          -62.5803 139.1672 -0.4497 0.6538  -338.3223  213.1618
# ZN:AGE:np.log(DIS):NOX                         0.0055   0.0055  1.0157 0.3120    -0.0053    0.0164
# RM:AGE:np.log(DIS):NOX                       431.9957 283.9271  1.5215 0.1310  -130.5695  994.5609
# ZN:RM:AGE:np.log(DIS):NOX                      0.0393   0.0400  0.9815 0.3285    -0.0400    0.1186
# INDUS:np.log(DIS):NOX                         97.6149 195.6735  0.4989 0.6189  -290.0869  485.3168
# ZN:INDUS:np.log(DIS):NOX                       0.0004   0.0008  0.5165 0.6065    -0.0011    0.0019
# RM:INDUS:np.log(DIS):NOX                     531.2197 598.9159  0.8870 0.3770  -655.4553 1717.8947
# ZN:RM:INDUS:np.log(DIS):NOX                    0.0037   0.0050  0.7502 0.4547    -0.0061    0.0136
# AGE:INDUS:np.log(DIS):NOX                   -472.7410 215.2096 -2.1967 0.0301  -899.1513  -46.3307
# ZN:AGE:INDUS:np.log(DIS):NOX                   0.0117   0.0136  0.8630 0.3900    -0.0152    0.0386
# RM:AGE:INDUS:np.log(DIS):NOX                  48.2641  41.0753  1.1750 0.2425   -33.1212  129.6495
# ZN:RM:AGE:INDUS:np.log(DIS):NOX                0.0877   0.0987  0.8885 0.3762    -0.1078    0.2832
# TAX:NOX                                     -441.2368 401.0834 -1.1001 0.2736 -1235.9321  353.4584
# ZN:TAX:NOX                                    -0.0038   0.0038 -1.0004 0.3193    -0.0113    0.0037
# RM:TAX:NOX                                  -131.7984  99.7640 -1.3211 0.1892  -329.4679   65.8711
# ZN:RM:TAX:NOX                                 -0.0425   0.0449 -0.9454 0.3465    -0.1315    0.0466
# AGE:TAX:NOX                                  -48.7180  35.3259 -1.3791 0.1706  -118.7117   21.2757
# ZN:AGE:TAX:NOX                                 0.0415   0.0240  1.7308 0.0862    -0.0060    0.0891
# RM:AGE:TAX:NOX                                10.5139   6.0878  1.7270 0.0869    -1.5483   22.5762
# ZN:RM:AGE:TAX:NOX                             -0.0354   0.0231 -1.5369 0.1271    -0.0811    0.0102
# INDUS:TAX:NOX                                 24.3384  19.2364  1.2652 0.2084   -13.7762   62.4529
# ZN:INDUS:TAX:NOX                              -0.0050   0.0168 -0.2951 0.7684    -0.0382    0.0283
# RM:INDUS:TAX:NOX                               7.4764   6.3530  1.1768 0.2418    -5.1113   20.0641
# ZN:RM:INDUS:TAX:NOX                           -0.0069   0.0162 -0.4289 0.6688    -0.0389    0.0251
# AGE:INDUS:TAX:NOX                              2.5648   2.1592  1.1878 0.2374    -1.7134    6.8429
# ZN:AGE:INDUS:TAX:NOX                           0.0476   0.0646  0.7371 0.4626    -0.0804    0.1756
# RM:AGE:INDUS:TAX:NOX                          -0.5604   0.3710 -1.5104 0.1338    -1.2956    0.1748
# ZN:RM:AGE:INDUS:TAX:NOX                       -0.0288   0.0384 -0.7506 0.4545    -0.1049    0.0473
# np.log(DIS):TAX:NOX                         -287.9914 600.4911 -0.4796 0.6325 -1477.7876  901.8048
# ZN:np.log(DIS):TAX:NOX                        -0.0047   0.0068 -0.6901 0.4916    -0.0181    0.0088
# RM:np.log(DIS):TAX:NOX                       161.3134 125.8218  1.2821 0.2025   -87.9863  410.6132
# ZN:RM:np.log(DIS):TAX:NOX                     -0.0662   0.0915 -0.7236 0.4708    -0.2475    0.1151
# AGE:np.log(DIS):TAX:NOX                       41.4571  25.0227  1.6568 0.1004    -8.1220   91.0363
# ZN:AGE:np.log(DIS):TAX:NOX                     0.0747   0.0459  1.6280 0.1063    -0.0162    0.1656
# RM:AGE:np.log(DIS):TAX:NOX                    -8.9069   4.5521 -1.9567 0.0529   -17.9263    0.1124
# ZN:RM:AGE:np.log(DIS):TAX:NOX                  0.0610   0.0638  0.9561 0.3411    -0.0654    0.1873
# INDUS:np.log(DIS):TAX:NOX                     38.8715  44.7974  0.8677 0.3874   -49.8887  127.6317
# ZN:INDUS:np.log(DIS):TAX:NOX                  -0.0210   0.0325 -0.6453 0.5200    -0.0853    0.0434
# RM:INDUS:np.log(DIS):TAX:NOX                 -12.2837   8.8796 -1.3834 0.1693   -29.8775    5.3101
# ZN:RM:INDUS:np.log(DIS):TAX:NOX               -0.0747   0.0840 -0.8893 0.3758    -0.2411    0.0917
# AGE:INDUS:np.log(DIS):TAX:NOX                 -1.8115   1.5829 -1.1444 0.2549    -4.9479    1.3249
# ZN:AGE:INDUS:np.log(DIS):TAX:NOX              -0.0636   0.0324 -1.9639 0.0520    -0.1278    0.0006
# RM:AGE:INDUS:np.log(DIS):TAX:NOX               0.4102   0.2825  1.4519 0.1493    -0.1496    0.9699
# ZN:RM:AGE:INDUS:np.log(DIS):TAX:NOX            0.0467   0.0270  1.7306 0.0863    -0.0068    0.1001
# LSTAT:NOX                                    -37.4958  71.6625 -0.5232 0.6018  -179.4858  104.4942
# ZN:LSTAT:NOX                                   0.0005   0.0005  0.9416 0.3484    -0.0005    0.0015
# RM:LSTAT:NOX                                -283.9561 474.9961 -0.5978 0.5512 -1225.0999  657.1876
# ZN:RM:LSTAT:NOX                                0.0027   0.0033  0.8223 0.4127    -0.0038    0.0092
# AGE:LSTAT:NOX                               -197.4879 481.4050 -0.4102 0.6824 -1151.3302  756.3543
# ZN:AGE:LSTAT:NOX                               0.0061   0.0052  1.1665 0.2459    -0.0043    0.0165
# RM:AGE:LSTAT:NOX                              73.1418  82.2520  0.8892 0.3758   -89.8300  236.1136
# ZN:RM:AGE:LSTAT:NOX                            0.0507   0.0451  1.1231 0.2638    -0.0387    0.1400
# INDUS:LSTAT:NOX                             -453.1402 213.4450 -2.1230 0.0360  -876.0541  -30.2264
# ZN:INDUS:LSTAT:NOX                             0.0007   0.0011  0.5792 0.5636    -0.0016    0.0029
# RM:INDUS:LSTAT:NOX                           139.4585  57.6127  2.4206 0.0171    25.3062  253.6108
# ZN:RM:INDUS:LSTAT:NOX                          0.0053   0.0080  0.6588 0.5114    -0.0106    0.0212
# AGE:INDUS:LSTAT:NOX                           11.0518  26.1620  0.4224 0.6735   -40.7849   62.8885
# ZN:AGE:INDUS:LSTAT:NOX                         0.0025   0.0059  0.4268 0.6703    -0.0092    0.0143
# RM:AGE:INDUS:LSTAT:NOX                        -4.4907   4.3886 -1.0233 0.3084   -13.1862    4.2048
# ZN:RM:AGE:INDUS:LSTAT:NOX                      0.0547   0.0583  0.9380 0.3503    -0.0609    0.1703
# np.log(DIS):LSTAT:NOX                         20.2362 122.0283  0.1658 0.8686  -221.5471  262.0196
# ZN:np.log(DIS):LSTAT:NOX                       0.0008   0.0008  0.9220 0.3585    -0.0009    0.0024
# RM:np.log(DIS):LSTAT:NOX                    -385.7007 870.0294 -0.4433 0.6584 -2109.5524 1338.1510
# ZN:RM:np.log(DIS):LSTAT:NOX                    0.0043   0.0057  0.7579 0.4501    -0.0069    0.0155
# AGE:np.log(DIS):LSTAT:NOX                   -325.4055 378.2278 -0.8603 0.3914 -1074.8154  424.0043
# ZN:AGE:np.log(DIS):LSTAT:NOX                   0.0075   0.0064  1.1847 0.2387    -0.0051    0.0201
# RM:AGE:np.log(DIS):LSTAT:NOX                  18.7895  72.6023  0.2588 0.7963  -125.0626  162.6417
# ZN:RM:AGE:np.log(DIS):LSTAT:NOX                0.0685   0.0554  1.2363 0.2189    -0.0413    0.1783
# INDUS:np.log(DIS):LSTAT:NOX                   10.9017 254.2869  0.0429 0.9659  -492.9352  514.7385
# ZN:INDUS:np.log(DIS):LSTAT:NOX                 0.0004   0.0020  0.2002 0.8417    -0.0035    0.0043
# RM:INDUS:np.log(DIS):LSTAT:NOX               -27.7499  73.9258 -0.3754 0.7081  -174.2244  118.7247
# ZN:RM:INDUS:np.log(DIS):LSTAT:NOX              0.0058   0.0131  0.4447 0.6574    -0.0201    0.0318
# AGE:INDUS:np.log(DIS):LSTAT:NOX               47.0911  22.7521  2.0697 0.0408     2.0107   92.1716
# ZN:AGE:INDUS:np.log(DIS):LSTAT:NOX            -0.0104   0.0126 -0.8225 0.4125    -0.0354    0.0146
# RM:AGE:INDUS:np.log(DIS):LSTAT:NOX            -5.3131   4.1400 -1.2833 0.2020   -13.5161    2.8898
# ZN:RM:AGE:INDUS:np.log(DIS):LSTAT:NOX          0.0083   0.0245  0.3375 0.7363    -0.0403    0.0568
# TAX:LSTAT:NOX                               -429.2340 250.1539 -1.7159 0.0889  -924.8819   66.4139
# ZN:TAX:LSTAT:NOX                              -0.0008   0.0059 -0.1313 0.8957    -0.0124    0.0109
# RM:TAX:LSTAT:NOX                              85.6201  43.5337  1.9668 0.0517    -0.6364  171.8767
# ZN:RM:TAX:LSTAT:NOX                           -0.0706   0.0290 -2.4327 0.0166    -0.1280   -0.0131
# AGE:TAX:LSTAT:NOX                              8.4709   3.4995  2.4206 0.0171     1.5371   15.4048
# ZN:AGE:TAX:LSTAT:NOX                          -0.0617   0.0496 -1.2422 0.2168    -0.1600    0.0367
# RM:AGE:TAX:LSTAT:NOX                          -1.6160   0.6146 -2.6296 0.0098    -2.8337   -0.3984
# ZN:RM:AGE:TAX:LSTAT:NOX                       -0.2141   0.1302 -1.6442 0.1029    -0.4721    0.0439
# INDUS:TAX:LSTAT:NOX                           24.9614  14.0100  1.7817 0.0775    -2.7977   52.7205
# ZN:INDUS:TAX:LSTAT:NOX                        -0.0155   0.0106 -1.4562 0.1481    -0.0365    0.0056
# RM:INDUS:TAX:LSTAT:NOX                        -4.9676   2.4672 -2.0134 0.0465    -9.8561   -0.0791
# ZN:RM:INDUS:TAX:LSTAT:NOX                      0.0087   0.0552  0.1579 0.8749    -0.1006    0.1180
# AGE:INDUS:TAX:LSTAT:NOX                       -0.4740   0.2040 -2.3236 0.0220    -0.8783   -0.0698
# ZN:AGE:INDUS:TAX:LSTAT:NOX                     0.0680   0.0482  1.4112 0.1609    -0.0275    0.1635
# RM:AGE:INDUS:TAX:LSTAT:NOX                     0.0905   0.0358  2.5265 0.0129     0.0195    0.1615
# ZN:RM:AGE:INDUS:TAX:LSTAT:NOX                  0.0484   0.0319  1.5158 0.1324    -0.0149    0.1117
# np.log(DIS):TAX:LSTAT:NOX                    422.6195 205.9552  2.0520 0.0425    14.5456  830.6933
# ZN:np.log(DIS):TAX:LSTAT:NOX                   0.0201   0.0251  0.7998 0.4255    -0.0297    0.0699
# RM:np.log(DIS):TAX:LSTAT:NOX                 -75.9791  35.5264 -2.1387 0.0346  -146.3701   -5.5881
# ZN:RM:np.log(DIS):TAX:LSTAT:NOX               -0.0418   0.0304 -1.3734 0.1724    -0.1021    0.0185
# AGE:np.log(DIS):TAX:LSTAT:NOX                 -6.0192   3.6835 -1.6341 0.1050   -13.3175    1.2792
# ZN:AGE:np.log(DIS):TAX:LSTAT:NOX              -0.0087   0.0325 -0.2691 0.7883    -0.0730    0.0556
# RM:AGE:np.log(DIS):TAX:LSTAT:NOX               1.1314   0.6315  1.7917 0.0759    -0.1198    2.3826
# ZN:RM:AGE:np.log(DIS):TAX:LSTAT:NOX            0.1046   0.0667  1.5689 0.1195    -0.0275    0.2367
# INDUS:np.log(DIS):TAX:LSTAT:NOX              -25.3976  11.6048 -2.1885 0.0307   -48.3910   -2.4041
# ZN:INDUS:np.log(DIS):TAX:LSTAT:NOX            -0.0152   0.0207 -0.7311 0.4663    -0.0562    0.0259
# RM:INDUS:np.log(DIS):TAX:LSTAT:NOX             4.5442   2.0121  2.2585 0.0259     0.5575    8.5309
# ZN:RM:INDUS:np.log(DIS):TAX:LSTAT:NOX          0.0045   0.0201  0.2240 0.8231    -0.0353    0.0444
# AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX            0.3098   0.2134  1.4514 0.1495    -0.1131    0.7326
# ZN:AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX        -0.0755   0.0563 -1.3414 0.1825    -0.1871    0.0360
# RM:AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX        -0.0589   0.0364 -1.6188 0.1083    -0.1310    0.0132
# ZN:RM:AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX     -0.0197   0.0140 -1.4043 0.1630    -0.0475    0.0081
# B                                           -522.1331 307.0974 -1.7002 0.0919 -1130.6072   86.3411
# ZN:B                                           0.0280   0.0206  1.3606 0.1764    -0.0128    0.0688
# RM:B                                          84.3499  50.2078  1.6800 0.0957   -15.1305  183.8304
# ZN:RM:B                                        0.0470   0.0634  0.7425 0.4594    -0.0785    0.1726
# AGE:B                                          5.0141   3.0392  1.6498 0.1018    -1.0076   11.0358
# ZN:AGE:B                                       0.1148   0.0725  1.5844 0.1159    -0.0288    0.2585
# RM:AGE:B                                      -1.1531   0.8463 -1.3626 0.1758    -2.8299    0.5237
# ZN:RM:AGE:B                                   -0.0160   0.0211 -0.7597 0.4490    -0.0579    0.0258
# INDUS:B                                       31.5820  17.8851  1.7658 0.0802    -3.8551   67.0191
# ZN:INDUS:B                                    -0.0020   0.0311 -0.0639 0.9492    -0.0636    0.0596
# RM:INDUS:B                                    -5.4716   2.7414 -1.9959 0.0484   -10.9033   -0.0398
# ZN:RM:INDUS:B                                 -0.0170   0.0166 -1.0260 0.3071    -0.0499    0.0159
# AGE:INDUS:B                                   -0.0874   0.2608 -0.3351 0.7381    -0.6042    0.4294
# ZN:AGE:INDUS:B                                -0.0205   0.0213 -0.9609 0.3387    -0.0628    0.0218
# RM:AGE:INDUS:B                                 0.0347   0.0562  0.6177 0.5380    -0.0766    0.1460
# ZN:RM:AGE:INDUS:B                              0.0060   0.0136  0.4431 0.6586    -0.0210    0.0330
# np.log(DIS):B                                443.9313 222.2133  1.9978 0.0482     3.6441  884.2185
# ZN:np.log(DIS):B                               0.0064   0.0395  0.1613 0.8721    -0.0720    0.0847
# RM:np.log(DIS):B                             -70.2454  36.0618 -1.9479 0.0539  -141.6973    1.2065
# ZN:RM:np.log(DIS):B                           -0.0716   0.0330 -2.1744 0.0318    -0.1369   -0.0064
# AGE:np.log(DIS):B                             -3.5624   2.4691 -1.4428 0.1519    -8.4545    1.3298
# ZN:AGE:np.log(DIS):B                          -0.0600   0.0663 -0.9046 0.3676    -0.1914    0.0714
# RM:AGE:np.log(DIS):B                           1.1324   0.6498  1.7427 0.0841    -0.1551    2.4199
# ZN:RM:AGE:np.log(DIS):B                        0.0082   0.0116  0.7049 0.4823    -0.0148    0.0312
# INDUS:np.log(DIS):B                          -27.0574  12.7454 -2.1229 0.0360   -52.3107   -1.8040
# ZN:INDUS:np.log(DIS):B                        -0.0649   0.0565 -1.1491 0.2530    -0.1768    0.0470
# RM:INDUS:np.log(DIS):B                         4.2815   2.1942  1.9513 0.0535    -0.0659    8.6290
# ZN:RM:INDUS:np.log(DIS):B                      0.0199   0.0339  0.5887 0.5572    -0.0472    0.0871
# AGE:INDUS:np.log(DIS):B                       -0.5897   0.3523 -1.6741 0.0969    -1.2877    0.1082
# ZN:AGE:INDUS:np.log(DIS):B                    -0.0243   0.0411 -0.5913 0.5555    -0.1057    0.0571
# RM:AGE:INDUS:np.log(DIS):B                     0.0658   0.0648  1.0158 0.3119    -0.0626    0.1943
# ZN:RM:AGE:INDUS:np.log(DIS):B                  0.0046   0.0059  0.7809 0.4365    -0.0071    0.0162
# TAX:B                                          2.3458   1.3176  1.7804 0.0777    -0.2648    4.9565
# ZN:TAX:B                                       0.0084   0.0178  0.4729 0.6372    -0.0268    0.0436
# RM:TAX:B                                      -0.6540   0.2260 -2.8942 0.0046    -1.1017   -0.2063
# ZN:RM:TAX:B                                    0.0021   0.0065  0.3228 0.7475    -0.0108    0.0150
# AGE:TAX:B                                     -0.0944   0.0473 -1.9977 0.0482    -0.1880   -0.0008
# ZN:AGE:TAX:B                                   0.0009   0.0017  0.5355 0.5934    -0.0025    0.0043
# RM:AGE:TAX:B                                   0.0188   0.0082  2.2922 0.0238     0.0025    0.0350
# ZN:RM:AGE:TAX:B                               -0.0002   0.0003 -0.7320 0.4657    -0.0009    0.0004
# INDUS:TAX:B                                   -0.1275   0.0680 -1.8763 0.0632    -0.2622    0.0071
# ZN:INDUS:TAX:B                                -0.0173   0.0122 -1.4262 0.1566    -0.0414    0.0068
# RM:INDUS:TAX:B                                 0.0348   0.0126  2.7686 0.0066     0.0099    0.0597
# ZN:RM:INDUS:TAX:B                              0.0014   0.0028  0.4870 0.6272    -0.0042    0.0069
# AGE:INDUS:TAX:B                                0.0049   0.0028  1.7205 0.0881    -0.0007    0.0105
# ZN:AGE:INDUS:TAX:B                            -0.0002   0.0004 -0.5736 0.5674    -0.0011    0.0006
# RM:AGE:INDUS:TAX:B                            -0.0010   0.0005 -1.9814 0.0500    -0.0019   -0.0000
# ZN:RM:AGE:INDUS:TAX:B                          0.0000   0.0001  0.1746 0.8617    -0.0002    0.0002
# np.log(DIS):TAX:B                             -2.8921   1.1540 -2.5062 0.0136    -5.1786   -0.6056
# ZN:np.log(DIS):TAX:B                          -0.0015   0.0133 -0.1103 0.9123    -0.0278    0.0248
# RM:np.log(DIS):TAX:B                           0.6230   0.2029  3.0709 0.0027     0.2210    1.0249
# ZN:RM:np.log(DIS):TAX:B                       -0.0016   0.0017 -0.9099 0.3648    -0.0049    0.0018
# AGE:np.log(DIS):TAX:B                          0.0796   0.0339  2.3514 0.0205     0.0125    0.1468
# ZN:AGE:np.log(DIS):TAX:B                      -0.0013   0.0010 -1.2315 0.2207    -0.0033    0.0008
# RM:AGE:np.log(DIS):TAX:B                      -0.0158   0.0061 -2.5926 0.0108    -0.0279   -0.0037
# ZN:RM:AGE:np.log(DIS):TAX:B                    0.0003   0.0002  1.3582 0.1771    -0.0001    0.0007
# INDUS:np.log(DIS):TAX:B                        0.2016   0.0767  2.6304 0.0097     0.0498    0.3535
# ZN:INDUS:np.log(DIS):TAX:B                     0.0097   0.0066  1.4567 0.1480    -0.0035    0.0228
# RM:INDUS:np.log(DIS):TAX:B                    -0.0391   0.0139 -2.8211 0.0057    -0.0666   -0.0116
# ZN:RM:INDUS:np.log(DIS):TAX:B                 -0.0009   0.0012 -0.7707 0.4425    -0.0032    0.0014
# AGE:INDUS:np.log(DIS):TAX:B                   -0.0036   0.0021 -1.7195 0.0883    -0.0078    0.0006
# ZN:AGE:INDUS:np.log(DIS):TAX:B                 0.0003   0.0003  1.1308 0.2606    -0.0003    0.0010
# RM:AGE:INDUS:np.log(DIS):TAX:B                 0.0007   0.0004  1.9454 0.0542    -0.0000    0.0015
# ZN:RM:AGE:INDUS:np.log(DIS):TAX:B             -0.0000   0.0001 -0.3029 0.7625    -0.0001    0.0001
# LSTAT:B                                       63.1326  31.1915  2.0240 0.0453     1.3307  124.9346
# ZN:LSTAT:B                                     0.0934   0.0585  1.5966 0.1132    -0.0225    0.2093
# RM:LSTAT:B                                   -10.9783   5.1655 -2.1253 0.0358   -21.2131   -0.7436
# ZN:RM:LSTAT:B                                  0.0250   0.0209  1.1974 0.2337    -0.0164    0.0663
# AGE:LSTAT:B                                   -1.1821   0.9640 -1.2263 0.2226    -3.0921    0.7278
# ZN:AGE:LSTAT:B                                -0.0126   0.0152 -0.8306 0.4080    -0.0427    0.0175
# RM:AGE:LSTAT:B                                 0.2549   0.1696  1.5028 0.1357    -0.0811    0.5909
# ZN:RM:AGE:LSTAT:B                             -0.0055   0.0051 -1.0693 0.2872    -0.0156    0.0047
# INDUS:LSTAT:B                                 -3.2388   2.1831 -1.4836 0.1407    -7.5643    1.0868
# ZN:INDUS:LSTAT:B                               0.0900   0.0658  1.3688 0.1738    -0.0403    0.2203
# RM:INDUS:LSTAT:B                               0.5869   0.3248  1.8066 0.0735    -0.0568    1.2305
# ZN:RM:INDUS:LSTAT:B                           -0.0148   0.0127 -1.1691 0.2449    -0.0399    0.0103
# AGE:INDUS:LSTAT:B                              0.0508   0.0589  0.8621 0.3905    -0.0659    0.1675
# ZN:AGE:INDUS:LSTAT:B                          -0.0169   0.0309 -0.5449 0.5869    -0.0782    0.0444
# RM:AGE:INDUS:LSTAT:B                          -0.0118   0.0098 -1.2014 0.2321    -0.0313    0.0077
# ZN:RM:AGE:INDUS:LSTAT:B                        0.0031   0.0059  0.5243 0.6011    -0.0086    0.0148
# np.log(DIS):LSTAT:B                          -58.3191  23.3726 -2.4952 0.0140  -104.6290  -12.0093
# ZN:np.log(DIS):LSTAT:B                         0.1267   0.0811  1.5621 0.1211    -0.0340    0.2875
# RM:np.log(DIS):LSTAT:B                         9.1467   3.9402  2.3214 0.0221     1.3396   16.9538
# ZN:RM:np.log(DIS):LSTAT:B                     -0.0138   0.0147 -0.9376 0.3505    -0.0430    0.0154
# AGE:np.log(DIS):LSTAT:B                        0.4474   0.5862  0.7632 0.4469    -0.7141    1.6090
# ZN:AGE:np.log(DIS):LSTAT:B                    -0.0424   0.0269 -1.5731 0.1185    -0.0957    0.0110
# RM:AGE:np.log(DIS):LSTAT:B                    -0.1257   0.1086 -1.1577 0.2495    -0.3409    0.0895
# ZN:RM:AGE:np.log(DIS):LSTAT:B                  0.0082   0.0059  1.3979 0.1649    -0.0034    0.0199
# INDUS:np.log(DIS):LSTAT:B                      2.1114   1.4242  1.4826 0.1410    -0.7104    4.9332
# ZN:INDUS:np.log(DIS):LSTAT:B                  -0.0530   0.0353 -1.4993 0.1366    -0.1230    0.0170
# RM:INDUS:np.log(DIS):LSTAT:B                  -0.3282   0.2396 -1.3699 0.1735    -0.8029    0.1465
# ZN:RM:INDUS:np.log(DIS):LSTAT:B                0.0029   0.0069  0.4125 0.6807    -0.0109    0.0166
# AGE:INDUS:np.log(DIS):LSTAT:B                  0.0359   0.0372  0.9649 0.3367    -0.0378    0.1096
# ZN:AGE:INDUS:np.log(DIS):LSTAT:B               0.0209   0.0182  1.1497 0.2527    -0.0151    0.0568
# RM:AGE:INDUS:np.log(DIS):LSTAT:B              -0.0029   0.0063 -0.4558 0.6494    -0.0154    0.0097
# ZN:RM:AGE:INDUS:np.log(DIS):LSTAT:B           -0.0033   0.0031 -1.0885 0.2787    -0.0094    0.0027
# TAX:LSTAT:B                                   -0.9840   0.4242 -2.3198 0.0222    -1.8245   -0.1436
# ZN:TAX:LSTAT:B                                 0.0043   0.0197  0.2168 0.8287    -0.0348    0.0434
# RM:TAX:LSTAT:B                                 0.1829   0.0726  2.5181 0.0132     0.0390    0.3268
# ZN:RM:TAX:LSTAT:B                             -0.0012   0.0037 -0.3391 0.7351    -0.0085    0.0060
# AGE:TAX:LSTAT:B                                0.0164   0.0057  2.8653 0.0050     0.0051    0.0278
# ZN:AGE:TAX:LSTAT:B                            -0.0003   0.0005 -0.5395 0.5906    -0.0013    0.0007
# RM:AGE:TAX:LSTAT:B                            -0.0030   0.0010 -3.0140 0.0032    -0.0050   -0.0010
# ZN:RM:AGE:TAX:LSTAT:B                         -0.0002   0.0001 -2.0269 0.0450    -0.0003   -0.0000
# INDUS:TAX:LSTAT:B                              0.0550   0.0227  2.4181 0.0172     0.0099    0.1000
# ZN:INDUS:TAX:LSTAT:B                           0.0009   0.0056  0.1607 0.8726    -0.0102    0.0121
# RM:INDUS:TAX:LSTAT:B                          -0.0102   0.0039 -2.5877 0.0109    -0.0179   -0.0024
# ZN:RM:INDUS:TAX:LSTAT:B                        0.0001   0.0011  0.0590 0.9531    -0.0021    0.0022
# AGE:INDUS:TAX:LSTAT:B                         -0.0009   0.0003 -2.8019 0.0060    -0.0015   -0.0003
# ZN:AGE:INDUS:TAX:LSTAT:B                       0.0002   0.0002  0.9336 0.3525    -0.0002    0.0005
# RM:AGE:INDUS:TAX:LSTAT:B                       0.0002   0.0001  2.9370 0.0040     0.0001    0.0003
# ZN:RM:AGE:INDUS:TAX:LSTAT:B                    0.0000   0.0000  1.5908 0.1145    -0.0000    0.0001
# np.log(DIS):TAX:LSTAT:B                        0.9345   0.3518  2.6561 0.0091     0.2374    1.6316
# ZN:np.log(DIS):TAX:LSTAT:B                    -0.0033   0.0094 -0.3455 0.7303    -0.0220    0.0155
# RM:np.log(DIS):TAX:LSTAT:B                    -0.1633   0.0598 -2.7284 0.0074    -0.2818   -0.0447
# ZN:RM:np.log(DIS):TAX:LSTAT:B                  0.0007   0.0017  0.4099 0.6827    -0.0026    0.0040
# AGE:np.log(DIS):TAX:LSTAT:B                   -0.0129   0.0057 -2.2798 0.0245    -0.0242   -0.0017
# ZN:AGE:np.log(DIS):TAX:LSTAT:B                 0.0004   0.0004  1.0255 0.3073    -0.0004    0.0011
# RM:AGE:np.log(DIS):TAX:LSTAT:B                 0.0023   0.0010  2.4245 0.0169     0.0004    0.0042
# ZN:RM:AGE:np.log(DIS):TAX:LSTAT:B              0.0000   0.0000  1.0849 0.2803    -0.0000    0.0001
# INDUS:np.log(DIS):TAX:LSTAT:B                 -0.0539   0.0188 -2.8642 0.0050    -0.0913   -0.0166
# ZN:INDUS:np.log(DIS):TAX:LSTAT:B              -0.0005   0.0026 -0.1854 0.8532    -0.0056    0.0047
# RM:INDUS:np.log(DIS):TAX:LSTAT:B               0.0093   0.0032  2.8881 0.0047     0.0029    0.0157
# ZN:RM:INDUS:np.log(DIS):TAX:LSTAT:B           -0.0000   0.0004 -0.0293 0.9767    -0.0009    0.0009
# AGE:INDUS:np.log(DIS):TAX:LSTAT:B              0.0007   0.0003  2.1111 0.0370     0.0000    0.0013
# ZN:AGE:INDUS:np.log(DIS):TAX:LSTAT:B          -0.0002   0.0002 -1.2117 0.2282    -0.0005    0.0001
# RM:AGE:INDUS:np.log(DIS):TAX:LSTAT:B          -0.0001   0.0001 -2.2490 0.0265    -0.0002   -0.0000
# ZN:RM:AGE:INDUS:np.log(DIS):TAX:LSTAT:B       -0.0000   0.0000 -0.3651 0.7158    -0.0000    0.0000
# NOX:B                                       1043.7539 634.9720  1.6438 0.1030  -214.3617 2301.8696
# ZN:NOX:B                                       0.0120   0.0100  1.2072 0.2299    -0.0077    0.0318
# RM:NOX:B                                    -167.7078 103.4490 -1.6212 0.1078  -372.6788   37.2632
# ZN:RM:NOX:B                                    0.0317   0.0155  2.0511 0.0426     0.0011    0.0624
# AGE:NOX:B                                     -8.8251   6.9744 -1.2654 0.2084   -22.6440    4.9938
# ZN:AGE:NOX:B                                   0.0275   0.0455  0.6039 0.5472    -0.0626    0.1176
# RM:AGE:NOX:B                                   2.0907   1.6758  1.2476 0.2148    -1.2296    5.4110
# ZN:RM:AGE:NOX:B                               -0.0175   0.0676 -0.2590 0.7961    -0.1515    0.1164
# INDUS:NOX:B                                  -64.3767  36.3628 -1.7704 0.0794  -136.4250    7.6715
# ZN:INDUS:NOX:B                                -0.0031   0.0109 -0.2877 0.7741    -0.0248    0.0185
# RM:INDUS:NOX:B                                12.1815   5.6249  2.1656 0.0325     1.0365   23.3265
# ZN:RM:INDUS:NOX:B                             -0.0196   0.0360 -0.5431 0.5882    -0.0910    0.0518
# AGE:INDUS:NOX:B                                0.3335   0.5292  0.6302 0.5298    -0.7151    1.3821
# ZN:AGE:INDUS:NOX:B                             0.0467   0.0718  0.6507 0.5166    -0.0956    0.1890
# RM:AGE:INDUS:NOX:B                            -0.1059   0.1100 -0.9623 0.3380    -0.3238    0.1121
# ZN:RM:AGE:INDUS:NOX:B                         -0.0062   0.0336 -0.1856 0.8531    -0.0728    0.0603
# np.log(DIS):NOX:B                           -882.8998 464.5833 -1.9004 0.0599 -1803.4121   37.6126
# ZN:np.log(DIS):NOX:B                           0.0060   0.0211  0.2824 0.7781    -0.0359    0.0478
# RM:np.log(DIS):NOX:B                         143.1796  76.1025  1.8814 0.0625    -7.6077  293.9669
# ZN:RM:np.log(DIS):NOX:B                        0.0141   0.0659  0.2145 0.8305    -0.1164    0.1447
# AGE:np.log(DIS):NOX:B                          7.7012   4.9281  1.5627 0.1209    -2.0633   17.4656
# ZN:AGE:np.log(DIS):NOX:B                      -0.0575   0.0360 -1.5978 0.1129    -0.1289    0.0138
# RM:AGE:np.log(DIS):NOX:B                      -2.3234   1.1641 -1.9959 0.0484    -4.6298   -0.0169
# ZN:RM:AGE:np.log(DIS):NOX:B                    0.0147   0.0227  0.6479 0.5184    -0.0302    0.0596
# INDUS:np.log(DIS):NOX:B                       53.8612  27.3507  1.9693 0.0514    -0.3307  108.0532
# ZN:INDUS:np.log(DIS):NOX:B                    -0.0283   0.0203 -1.3910 0.1670    -0.0685    0.0120
# RM:INDUS:np.log(DIS):NOX:B                   -10.1004   4.8653 -2.0760 0.0402   -19.7405   -0.4604
# ZN:RM:INDUS:np.log(DIS):NOX:B                  0.0360   0.0698  0.5155 0.6072    -0.1023    0.1742
# AGE:INDUS:np.log(DIS):NOX:B                    0.7427   0.6148  1.2080 0.2296    -0.4755    1.9609
# ZN:AGE:INDUS:np.log(DIS):NOX:B                 0.0591   0.0768  0.7689 0.4436    -0.0931    0.2113
# RM:AGE:INDUS:np.log(DIS):NOX:B                -0.0483   0.1166 -0.4145 0.6793    -0.2793    0.1827
# ZN:RM:AGE:INDUS:np.log(DIS):NOX:B             -0.0095   0.0118 -0.8066 0.4216    -0.0329    0.0139
# TAX:NOX:B                                     -3.3903   2.4717 -1.3716 0.1729    -8.2877    1.5071
# ZN:TAX:NOX:B                                  -0.0221   0.0325 -0.6808 0.4974    -0.0866    0.0423
# RM:TAX:NOX:B                                   1.0553   0.4033  2.6166 0.0101     0.2562    1.8544
# ZN:RM:TAX:NOX:B                               -0.0044   0.0145 -0.3068 0.7595    -0.0331    0.0242
# AGE:TAX:NOX:B                                  0.1650   0.0889  1.8571 0.0659    -0.0110    0.3411
# ZN:AGE:TAX:NOX:B                              -0.0035   0.0042 -0.8365 0.4046    -0.0117    0.0048
# RM:AGE:TAX:NOX:B                              -0.0333   0.0154 -2.1643 0.0326    -0.0638   -0.0028
# ZN:RM:AGE:TAX:NOX:B                            0.0009   0.0007  1.2570 0.2114    -0.0005    0.0022
# INDUS:TAX:NOX:B                                0.1886   0.1237  1.5247 0.1302    -0.0565    0.4336
# ZN:INDUS:TAX:NOX:B                             0.0411   0.0285  1.4397 0.1527    -0.0155    0.0976
# RM:INDUS:TAX:NOX:B                            -0.0589   0.0217 -2.7125 0.0077    -0.1019   -0.0159
# ZN:RM:INDUS:TAX:NOX:B                         -0.0035   0.0057 -0.6139 0.5405    -0.0149    0.0078
# AGE:INDUS:TAX:NOX:B                           -0.0088   0.0054 -1.6400 0.1038    -0.0194    0.0018
# ZN:AGE:INDUS:TAX:NOX:B                        -0.0002   0.0010 -0.1750 0.8614    -0.0021    0.0018
# RM:AGE:INDUS:TAX:NOX:B                         0.0018   0.0009  1.9309 0.0560    -0.0000    0.0036
# ZN:RM:AGE:INDUS:TAX:NOX:B                      0.0000   0.0002  0.0880 0.9300    -0.0004    0.0004
# np.log(DIS):TAX:NOX:B                          4.4822   2.3382  1.9169 0.0578    -0.1507    9.1151
# ZN:np.log(DIS):TAX:NOX:B                       0.0028   0.0264  0.1070 0.9150    -0.0494    0.0551
# RM:np.log(DIS):TAX:NOX:B                      -1.0128   0.4015 -2.5225 0.0131    -1.8083   -0.2173
# ZN:RM:np.log(DIS):TAX:NOX:B                    0.0046   0.0046  0.9939 0.3224    -0.0046    0.0137
# AGE:np.log(DIS):TAX:NOX:B                     -0.1386   0.0612 -2.2629 0.0256    -0.2599   -0.0172
# ZN:AGE:np.log(DIS):TAX:NOX:B                   0.0023   0.0025  0.9146 0.3624    -0.0027    0.0072
# RM:AGE:np.log(DIS):TAX:NOX:B                   0.0280   0.0112  2.5070 0.0136     0.0059    0.0501
# ZN:RM:AGE:np.log(DIS):TAX:NOX:B               -0.0007   0.0004 -1.6535 0.1010    -0.0015    0.0001
# INDUS:np.log(DIS):TAX:NOX:B                   -0.3128   0.1399 -2.2353 0.0274    -0.5901   -0.0355
# ZN:INDUS:np.log(DIS):TAX:NOX:B                -0.0214   0.0155 -1.3798 0.1704    -0.0522    0.0093
# RM:INDUS:np.log(DIS):TAX:NOX:B                 0.0654   0.0248  2.6349 0.0096     0.0162    0.1147
# ZN:RM:INDUS:np.log(DIS):TAX:NOX:B              0.0018   0.0027  0.6596 0.5109    -0.0035    0.0071
# AGE:INDUS:np.log(DIS):TAX:NOX:B                0.0065   0.0038  1.6948 0.0929    -0.0011    0.0141
# ZN:AGE:INDUS:np.log(DIS):TAX:NOX:B            -0.0001   0.0006 -0.2367 0.8133    -0.0013    0.0010
# RM:AGE:INDUS:np.log(DIS):TAX:NOX:B            -0.0013   0.0007 -1.9562 0.0529    -0.0027    0.0000
# ZN:RM:AGE:INDUS:np.log(DIS):TAX:NOX:B         -0.0000   0.0001 -0.3546 0.7235    -0.0002    0.0002
# LSTAT:NOX:B                                 -123.1697  62.9234 -1.9575 0.0528  -247.8443    1.5049
# ZN:LSTAT:NOX:B                                 0.0312   0.0196  1.5927 0.1141    -0.0076    0.0700
# RM:LSTAT:NOX:B                                20.6713  10.4181  1.9842 0.0497     0.0291   41.3135
# ZN:RM:LSTAT:NOX:B                             -0.0425   0.0272 -1.5644 0.1205    -0.0964    0.0113
# AGE:LSTAT:NOX:B                                1.7634   1.6646  1.0594 0.2917    -1.5348    5.0617
# ZN:AGE:LSTAT:NOX:B                             0.0291   0.0233  1.2477 0.2148    -0.0171    0.0752
# RM:AGE:LSTAT:NOX:B                            -0.3919   0.2850 -1.3751 0.1718    -0.9566    0.1728
# ZN:RM:AGE:LSTAT:NOX:B                          0.0090   0.0081  1.1029 0.2724    -0.0072    0.0251
# INDUS:LSTAT:NOX:B                              9.6095   3.7960  2.5315 0.0127     2.0882   17.1309
# ZN:INDUS:LSTAT:NOX:B                           0.0425   0.0228  1.8647 0.0648    -0.0027    0.0878
# RM:INDUS:LSTAT:NOX:B                          -1.7393   0.6170 -2.8191 0.0057    -2.9618   -0.5168
# ZN:RM:INDUS:LSTAT:NOX:B                       -0.0067   0.0458 -0.1471 0.8833    -0.0976    0.0841
# AGE:INDUS:LSTAT:NOX:B                         -0.1145   0.0911 -1.2574 0.2112    -0.2950    0.0659
# ZN:AGE:INDUS:LSTAT:NOX:B                       0.0239   0.0678  0.3520 0.7255    -0.1105    0.1583
# RM:AGE:INDUS:LSTAT:NOX:B                       0.0257   0.0153  1.6761 0.0965    -0.0047    0.0560
# ZN:RM:AGE:INDUS:LSTAT:NOX:B                   -0.0054   0.0129 -0.4162 0.6781    -0.0309    0.0202
# np.log(DIS):LSTAT:NOX:B                      110.9969  47.6324  2.3303 0.0216    16.6194  205.3744
# ZN:np.log(DIS):LSTAT:NOX:B                     0.0464   0.0263  1.7626 0.0807    -0.0058    0.0985
# RM:np.log(DIS):LSTAT:NOX:B                   -17.0946   8.4082 -2.0331 0.0444   -33.7545   -0.4348
# ZN:RM:np.log(DIS):LSTAT:NOX:B                 -0.0320   0.0507 -0.6315 0.5290    -0.1324    0.0684
# AGE:np.log(DIS):LSTAT:NOX:B                   -0.2927   1.1026 -0.2655 0.7911    -2.4773    1.8919
# ZN:AGE:np.log(DIS):LSTAT:NOX:B                 0.0922   0.0604  1.5254 0.1300    -0.0275    0.2118
# RM:AGE:np.log(DIS):LSTAT:NOX:B                 0.1356   0.2080  0.6520 0.5158    -0.2765    0.5476
# ZN:RM:AGE:np.log(DIS):LSTAT:NOX:B             -0.0181   0.0133 -1.3600 0.1766    -0.0445    0.0083
# INDUS:np.log(DIS):LSTAT:NOX:B                 -7.3841   2.5065 -2.9460 0.0039   -12.3503   -2.4178
# ZN:INDUS:np.log(DIS):LSTAT:NOX:B              -0.0281   0.0260 -1.0816 0.2818    -0.0795    0.0234
# RM:INDUS:np.log(DIS):LSTAT:NOX:B               1.2718   0.4766  2.6688 0.0087     0.3276    2.2161
# ZN:RM:INDUS:np.log(DIS):LSTAT:NOX:B            0.0133   0.0301  0.4418 0.6595    -0.0464    0.0730
# AGE:INDUS:np.log(DIS):LSTAT:NOX:B             -0.0454   0.0622 -0.7300 0.4669    -0.1685    0.0778
# ZN:AGE:INDUS:np.log(DIS):LSTAT:NOX:B          -0.0395   0.0389 -1.0162 0.3117    -0.1165    0.0375
# RM:AGE:INDUS:np.log(DIS):LSTAT:NOX:B           0.0013   0.0114  0.1149 0.9087    -0.0213    0.0239
# ZN:RM:AGE:INDUS:np.log(DIS):LSTAT:NOX:B        0.0060   0.0067  0.8912 0.3747    -0.0074    0.0194
# TAX:LSTAT:NOX:B                                1.6061   0.7320  2.1942 0.0303     0.1558    3.0564
# ZN:TAX:LSTAT:NOX:B                            -0.0075   0.0440 -0.1695 0.8657    -0.0947    0.0798
# RM:TAX:LSTAT:NOX:B                            -0.3004   0.1251 -2.4016 0.0180    -0.5483   -0.0526
# ZN:RM:TAX:LSTAT:NOX:B                          0.0029   0.0085  0.3341 0.7389    -0.0141    0.0198
# AGE:TAX:LSTAT:NOX:B                           -0.0267   0.0098 -2.7230 0.0075    -0.0461   -0.0073
# ZN:AGE:TAX:LSTAT:NOX:B                         0.0010   0.0014  0.7333 0.4649    -0.0017    0.0037
# RM:AGE:TAX:LSTAT:NOX:B                         0.0049   0.0017  2.8938 0.0046     0.0016    0.0083
# ZN:RM:AGE:TAX:LSTAT:NOX:B                      0.0003   0.0002  1.9085 0.0589    -0.0000    0.0007
# INDUS:TAX:LSTAT:NOX:B                         -0.0944   0.0409 -2.3047 0.0230    -0.1755   -0.0132
# ZN:INDUS:TAX:LSTAT:NOX:B                      -0.0035   0.0123 -0.2889 0.7732    -0.0278    0.0208
# RM:INDUS:TAX:LSTAT:NOX:B                       0.0176   0.0071  2.4948 0.0141     0.0036    0.0316
# ZN:RM:INDUS:TAX:LSTAT:NOX:B                    0.0001   0.0023  0.0370 0.9706    -0.0045    0.0047
# AGE:INDUS:TAX:LSTAT:NOX:B                      0.0015   0.0006  2.6794 0.0085     0.0004    0.0026
# ZN:AGE:INDUS:TAX:LSTAT:NOX:B                  -0.0004   0.0004 -0.9845 0.3270    -0.0012    0.0004
# RM:AGE:INDUS:TAX:LSTAT:NOX:B                  -0.0003   0.0001 -2.8446 0.0053    -0.0005   -0.0001
# ZN:RM:AGE:INDUS:TAX:LSTAT:NOX:B               -0.0001   0.0000 -1.8356 0.0691    -0.0002    0.0000
# np.log(DIS):TAX:LSTAT:NOX:B                   -1.5320   0.6259 -2.4479 0.0159    -2.7721   -0.2920
# ZN:np.log(DIS):TAX:LSTAT:NOX:B                 0.0046   0.0210  0.2209 0.8255    -0.0369    0.0462
# RM:np.log(DIS):TAX:LSTAT:NOX:B                 0.2674   0.1060  2.5232 0.0130     0.0574    0.4773
# ZN:RM:np.log(DIS):TAX:LSTAT:NOX:B             -0.0014   0.0041 -0.3453 0.7305    -0.0096    0.0067
# AGE:np.log(DIS):TAX:LSTAT:NOX:B                0.0199   0.0100  1.9953 0.0484     0.0001    0.0396
# ZN:AGE:np.log(DIS):TAX:LSTAT:NOX:B            -0.0008   0.0008 -1.0730 0.2856    -0.0024    0.0007
# RM:AGE:np.log(DIS):TAX:LSTAT:NOX:B            -0.0036   0.0017 -2.1309 0.0353    -0.0070   -0.0003
# ZN:RM:AGE:np.log(DIS):TAX:LSTAT:NOX:B         -0.0001   0.0001 -1.1176 0.2661    -0.0003    0.0001
# INDUS:np.log(DIS):TAX:LSTAT:NOX:B              0.0924   0.0348  2.6586 0.0090     0.0235    0.1613
# ZN:INDUS:np.log(DIS):TAX:LSTAT:NOX:B           0.0021   0.0059  0.3494 0.7274    -0.0096    0.0137
# RM:INDUS:np.log(DIS):TAX:LSTAT:NOX:B          -0.0161   0.0059 -2.7145 0.0077    -0.0278   -0.0043
# ZN:RM:INDUS:np.log(DIS):TAX:LSTAT:NOX:B       -0.0001   0.0010 -0.0834 0.9337    -0.0021    0.0019
# AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX:B         -0.0011   0.0006 -1.8687 0.0643    -0.0022    0.0001
# ZN:AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX:B       0.0004   0.0003  1.1489 0.2531    -0.0003    0.0011
# RM:AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX:B       0.0002   0.0001  2.0121 0.0466     0.0000    0.0004
# ZN:RM:AGE:INDUS:np.log(DIS):TAX:LSTAT:NOX:B    0.0000   0.0000  0.4690 0.6400    -0.0000    0.0001
# --------------------------------------------------------------------------------------------------
# Omnibus:                      83.469              Durbin-Watson:                 1.673
# Prob(Omnibus):                0.000               Jarque-Bera (JB):              1304.784
# Skew:                         0.129               Prob(JB):                      0.000
# Kurtosis:                     11.283              Condition No.:                 19179687685898372
# ==================================================================================================
# * The condition number is large (2e+16). This might indicate             strong multicollinearity
# or other numerical problems.

# %%
from sklearn import  metrics
metrics.r2_score(bos.PRICE, model.predict(bos))
# Out:
# 0.9879824583770186

# %%
from sklearn import  metrics
metrics.r2_score(bos1.PRICE, model.predict(bos1))
# Out:
# -6927.556439368322
