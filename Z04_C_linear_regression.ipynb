# %% [markdown]
# # Regresja liniowa
#
# Naszym Celem jest empityczne sprawdzenie twierdzenia:
#
# Niech $A \in \mathbb{R}^{N\times K}$ będzie macierzą która przekształca $\mathbb{R}^{K}$ w $\mathbb{R}^N$, i niech $y \in \mathbb{R}^{K}$.
#
# Wtedy punkt $x_0 \in \mathbb{R}^K$ spełnia
#
# $$
# x_0 = \mathrm{argmin} \{ x \in \mathbb{R}^K   \colon \| Ax - y \|^2 \}
# $$
#
# wtedy i tylko wtedy gdy
#
# $$
# A^TA x_0 = A^Ty.
# $$

# %%
import numpy as np
import scipy.stats as st
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę wykres funkcji w kształcie
#
# $
# f(x)=x^2
# $
#
# na odcinku $[0,3]$ i go narysować.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: (x**2)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)=x^2$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
# We create the model.
lr = lm.LinearRegression()
# We train the model on our training dataset.
lr.fit(x[:, np.newaxis], y);
print(lr.coef_)
print(lr.intercept_)
# Out:
# [2.85515258]
# -1.0388310020856797

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr = lambda x: lr.coef_ * x +lr.intercept_

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Teraz możemy wykonać predykcję dla punktu
# $$
# x_0 = 1.5
# $$

# %%
point = np.array([1.5])
y_point = lr.predict(point[:, np.newaxis])

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.plot(point, y_point, 'or', ms=10);
plt.show()

# %% [markdown]
# Możemy wypisać miarę dopasowania $R^2$. Narazie nie wnikamy w to co ona oznacza.

# %%
from sklearn.metrics import r2_score
print(lr.score(x[:, np.newaxis], y))
print(r2_score(lr.predict(x[:, np.newaxis]), y))
# Out:
# 0.7967554750102797
# 0.7449097855435534

# %% [markdown]
# # Zadanie 1
# Stwórz macierz postaci:
# $$
# A=\begin{bmatrix}
# x_1 & 1\\
# \ddots & \ddots\\
# x_n & 1\\
# \end{bmatrix}
# $$
#
# i rozwiąż równanie
#
# $$
# A^TA x = A^Ty.
# $$
#
# gdzie (x,y) to nasz zbiór treningowy.
#
# Użyj funkcji <tt>linalg.solve</tt>.

# %%
deg=1
xx=np.vander(x, deg + 1)
xx
# Out:
# array([[0.2, 1. ],
#        [0.5, 1. ],
#        [0.8, 1. ],
#        [0.9, 1. ],
#        [1.3, 1. ],
#        [1.7, 1. ],
#        [2.1, 1. ],
#        [2.7, 1. ]])

# %% [markdown]
# ax=b

# %%
x0=np.linalg.solve(a=np.dot(xx.T,xx), b=np.dot(xx.T,y))
x0
# Out:
# array([ 2.85515258, -1.038831  ])

# %% [markdown]
# # Zadanie 2
# Zapoznaj się z funkcją <tt>optimize.fmin_cg</tt>
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fmin_cg.html
# i znajdż minum funkcji
#
# $$
# f(x,y) = (x+1)^2+y^2
# $$

# %%
from scipy import optimize

x0 = [1, 1]


def f(X):
    x, y = X
    return (x+1)**2+y**2


# f((1, 2))

optimize.fmin_cg(f, x0)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 9
#          Gradient evaluations: 3
# array([-1.00000010e+00, -4.94545107e-08])

# %%
def g(X, power):
    x, y = X
    return (x+1)**power+y**power

optimize.fmin_cg(g, x0, args=(2,))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 9
#          Gradient evaluations: 3
# array([-1.00000010e+00, -4.94545107e-08])

# %% [markdown]
# # Zadanie 3
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error}(a,b;(x,y)) =  \sum_{i=1}^{n} ( y_i - (ax_i+b) )^2.
# $$

# %%
def compute_error(Beta, X):
    a,b = Beta
    return np.sum([(y - (a * x + b))**2 for (x, y) in X])

# %% [markdown]
# # Zadanie 4
# Zminimalizuj funkcją $\mathrm{compute\_error}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
optimize.fmin_cg(compute_error, x0, args=(np.array([x, y]).T,))
# Out:
# Optimization terminated successfully.
#          Current function value: 10.428537
#          Iterations: 18
#          Function evaluations: 84
#          Gradient evaluations: 28
# array([ 2.85515192, -1.03882986])

# %% [markdown]
# # Zadanie 5
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error\_1}(a,b;(x,y)) =  \sum_{i=1}^{n} |y_i - (ax_i+b)|.
# $$

# %%
def compute_error_1(Beta, X):
    a,b = Beta
    return np.sum([np.abs(y - (a * x + b)) for (x, y) in X])

# %% [markdown]
# # Zadanie 6
# Zminimalizuj funkcją $\mathrm{compute\_error\_1}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
optimize.fmin_cg(compute_error, x0, args=(np.array([x, y]).T,))
# Out:
# Optimization terminated successfully.
#          Current function value: 77.905133
#          Iterations: 5
#          Function evaluations: 48
#          Gradient evaluations: 16
# array([-0.56761107,  3.14422213])

# %% [markdown]
# # Zadanie 7
# Wykonaj dwie powyższe regresję na danych z wartością odstającą.

# %%
f = lambda x: (x)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))/5
y[1]=y[1]+10
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
points = np.column_stack((x,y))

# %%
[b,a] = optimize.fmin_cg(compute_error, x0, args=(points,))

plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
x_model = np.linspace(0., 3, 200)
y_model = a * x_model + b
plt.plot(x_model, y_model, 'g');
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 77.905133
#          Iterations: 5
#          Function evaluations: 48
#          Gradient evaluations: 16

# %%
[b,a] = optimize.fmin_cg(compute_error_1            , x0, args=(points,))

plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])                                                                               
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
x_model = np.linspace(0., 3, 200)
y_model = a * x_model + b
plt.plot(x_model, y_model, 'g');
plt.show()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.954291
#          Iterations: 2
#          Function evaluations: 221
#          Gradient evaluations: 73
